# %%
import pandas as pd
dataset = pd.read_csv("Naive bayes dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 dataset = pd.read_csv("Naive bayes dataset.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Naive bayes dataset.csv'

# %%
# Assign X and y
X = dataset["Text"]
y = dataset["Label"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Assign X and y
# ----> 2 X = dataset["Text"]
#       3 y = dataset["Label"]
#
# NameError: name 'dataset' is not defined

# %%
# Train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0, stratify=y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Train-test split
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0, stratify=y)
#
# NameError: name 'X' is not defined

# %%
# Convert text into numerical features
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X_train = cv.fit_transform(X_train)
X_test = cv.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 from sklearn.feature_extraction.text import CountVectorizer
#       3 cv = CountVectorizer()
# ----> 4 X_train = cv.fit_transform(X_train)
#       5 X_test = cv.transform(X_test)
#
# NameError: name 'X_train' is not defined

# %%
# Import Naive Bayes model
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

# %%
# Train model
nb.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Train model
# ----> 2 nb.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
# Predict
y_pred = nb.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Predict
# ----> 2 y_pred = nb.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
# Evaluate accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy) 
print("Actual:", y_test.values)
print("Predicted:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Evaluate accuracy
#       2 from sklearn.metrics import accuracy_score
# ----> 3 accuracy = accuracy_score(y_test, y_pred)
#       4 print("Accuracy:", accuracy)
#       5 print("Actual:", y_test.values)
#
# NameError: name 'y_test' is not defined

# %%
# Test with new sentence
sample = ["This product is amazing"]
sample_vector = cv.transform(sample)
prediction = nb.predict(sample_vector)
print("Prediction:", prediction)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Test with new sentence
#       2 sample = ["This product is amazing"]
# ----> 3 sample_vector = cv.transform(sample)
#       4 prediction = nb.predict(sample_vector)
#       5 print("Prediction:", prediction)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1419, in CountVectorizer.transform(self, raw_documents)
#    1415 if isinstance(raw_documents, str):
#    1416     raise ValueError(
#    1417         "Iterable over raw text documents expected, string object received."
#    1418     )
# -> 1419 self._check_vocabulary()
#    1421 # use the same matrix-building strategy as fit_transform
#    1422 _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:501, in _VectorizerMixin._check_vocabulary(self)
#     499     self._validate_vocabulary()
#     500     if not self.fixed_vocabulary_:
# --> 501         raise NotFittedError("Vocabulary not fitted or provided")
#     503 if len(self.vocabulary_) == 0:
#     504     raise ValueError("Vocabulary is empty")
#
# NotFittedError: Vocabulary not fitted or provided
